# %%
#ANIMESH PATHAK 1928152 AP-LAB ASSIGNMENT-5

import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd  
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

df1 = pd.read_csv('C:\\Users\\KIIT\\Downloads\\boston.csv')
df1.describe()

scaler = MinMaxScaler()
df_norm = pd.DataFrame(scaler.fit_transform(df1), columns=df1.columns)
print("Normal Data")
print(df_norm)
# Out:
# Normal Data
#      Unnamed: 0      crim    zn     indus  chas       nox        rm       age  \
# 0      0.000000  0.000000  0.18  0.067815   0.0  0.314815  0.577505  0.641607
# 1      0.001980  0.000236  0.00  0.242302   0.0  0.172840  0.547998  0.782698
# 2      0.003960  0.000236  0.00  0.242302   0.0  0.172840  0.694386  0.599382
# 3      0.005941  0.000293  0.00  0.063050   0.0  0.150206  0.658555  0.441813
# 4      0.007921  0.000705  0.00  0.063050   0.0  0.150206  0.687105  0.528321
# ..          ...       ...   ...       ...   ...       ...       ...       ...
# 501    0.992079  0.000633  0.00  0.420455   0.0  0.386831  0.580954  0.681771
# 502    0.994059  0.000438  0.00  0.420455   0.0  0.386831  0.490324  0.760041
# 503    0.996040  0.000612  0.00  0.420455   0.0  0.386831  0.654340  0.907312
# 504    0.998020  0.001161  0.00  0.420455   0.0  0.386831  0.619467  0.889804
# 505    1.000000  0.000462  0.00  0.420455   0.0  0.386831  0.473079  0.802266
#
# ...

# %%
sns.scatterplot(data=df_norm,x='medv',y='lstat')
# Out:
# <AxesSubplot:xlabel='medv', ylabel='lstat'>

# %%
sns.scatterplot(data=df_norm,x='medv',y='black')
# Out:
# <AxesSubplot:xlabel='medv', ylabel='black'>

# %%
sns.scatterplot(data=df_norm,x='medv',y='ptratio')
# Out:
# <AxesSubplot:xlabel='medv', ylabel='ptratio'>

# %%
sns.scatterplot(data=df_norm,x='medv',y='tax')
# Out:
# <AxesSubplot:xlabel='medv', ylabel='tax'>

# %%
sns.scatterplot(data=df_norm,x='medv',y='rad')
# Out:
# <AxesSubplot:xlabel='medv', ylabel='rad'>

# %%
sns.scatterplot(data=df_norm,x='medv',y='dis')
# Out:
# <AxesSubplot:xlabel='medv', ylabel='dis'>

# %%
sns.scatterplot(data=df_norm,x='medv',y='age')
# Out:
# <AxesSubplot:xlabel='medv', ylabel='age'>

# %%
sns.scatterplot(data=df_norm,x='medv',y='rm')
# Out:
# <AxesSubplot:xlabel='medv', ylabel='rm'>

# %%
sns.scatterplot(data=df_norm,x='medv',y='nox')
# Out:
# <AxesSubplot:xlabel='medv', ylabel='nox'>

# %%
sns.scatterplot(data=df_norm,x='medv',y='chas')
# Out:
# <AxesSubplot:xlabel='medv', ylabel='chas'>

# %%
sns.scatterplot(data=df_norm,x='medv',y='indus')
# Out:
# <AxesSubplot:xlabel='medv', ylabel='indus'>

# %%
sns.scatterplot(data=df_norm,x='medv',y='zn')
# Out:
# <AxesSubplot:xlabel='medv', ylabel='zn'>

# %%
sns.scatterplot(data=df_norm,x='medv',y='crim')
# Out:
# <AxesSubplot:xlabel='medv', ylabel='crim'>

# %%
feature = ['lstat','rm','ptratio','crim','zn','indus','chas','nox','age','dis','rad','tax','black']
target = df_norm['medv']

for i, col in enumerate(feature):
    plt.subplot(1, len(feature), i + 1)
    x = df_norm[col]
    y = target
    plt.scatter(x, y, marker = 'x')
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('medv')

# %%
X= pd.DataFrame(np.c_[df1['lstat'],df1['rm']],columns=['lstat','rm'])
Y= df1['medv']

from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=5)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (404, 2)
# (102, 2)
# (404,)
# (102,)

# %%
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, Y_train)
LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
print(model.intercept_)
print(model.coef_)
train_score=model.score(X_train, Y_train)
test_score=model.score(X_test, Y_test)
print(train_score)
print(test_score)
# Out:
# 2.7362403426066173
# [-0.71722954  4.58938833]
# 0.6300745149331701
# 0.6628996975186953

# %%
y_train_predict = model.predict(X_train)
rmse=(np.sqrt(mean_squared_error(Y_train,y_train_predict)))
r2=r2_score(Y_train,y_train_predict)
print('RMSE :',rmse,'R2_SCORE: ',r2)
plt.plot((mean_squared_error(Y_train,y_train_predict)))
plt.show()
# Out:
# RMSE : 5.6371293350711955 R2_SCORE:  0.6300745149331701

# %%
y_test_predict = model.predict(X_test)
rmse=(np.sqrt(mean_squared_error(Y_test,y_test_predict)))
r2=r2_score(Y_test,y_test_predict)
print('RMSE :',rmse,'R2_SCORE: ',r2)
# Out:
# RMSE : 5.137400784702911 R2_SCORE:  0.6628996975186953
