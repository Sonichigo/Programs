# %%
# Using In-built Functions

import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd  
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

df1 = pd.read_csv('C:\\Users\\KIIT\\Downloads\\boston.csv')
df1.describe()

scaler = MinMaxScaler()
df_norm = pd.DataFrame(scaler.fit_transform(df1), columns=df1.columns)
print("Normal Data")
print(df_norm)

std_scaler = StandardScaler()
df_std = pd.DataFrame(std_scaler.fit_transform(df1), columns=df1.columns)
print("Standard Data")
print(df_std)

corr = df1.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(222, 270, n=7),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    ha='right'
);
# Out:
# Normal Data
#      Unnamed: 0      crim    zn     indus  chas       nox        rm       age  \
# 0      0.000000  0.000000  0.18  0.067815   0.0  0.314815  0.577505  0.641607
# 1      0.001980  0.000236  0.00  0.242302   0.0  0.172840  0.547998  0.782698
# 2      0.003960  0.000236  0.00  0.242302   0.0  0.172840  0.694386  0.599382
# 3      0.005941  0.000293  0.00  0.063050   0.0  0.150206  0.658555  0.441813
# 4      0.007921  0.000705  0.00  0.063050   0.0  0.150206  0.687105  0.528321
# ..          ...       ...   ...       ...   ...       ...       ...       ...
# 501    0.992079  0.000633  0.00  0.420455   0.0  0.386831  0.580954  0.681771
# 502    0.994059  0.000438  0.00  0.420455   0.0  0.386831  0.490324  0.760041
# 503    0.996040  0.000612  0.00  0.420455   0.0  0.386831  0.654340  0.907312
# 504    0.998020  0.001161  0.00  0.420455   0.0  0.386831  0.619467  0.889804
# 505    1.000000  0.000462  0.00  0.420455   0.0  0.386831  0.473079  0.802266
#
#           dis       rad       tax   ptratio     black     lstat      medv
# 0    0.269203  0.000000  0.208015  0.287234  1.000000  0.089680  0.422222
# 1    0.348962  0.043478  0.104962  0.553191  1.000000  0.204470  0.368889
# 2    0.348962  0.043478  0.104962  0.553191  0.989737  0.063466  0.660000
# 3    0.448545  0.086957  0.066794  0.648936  0.994276  0.033389  0.631111
# 4    0.448545  0.086957  0.066794  0.648936  1.000000  0.099338  0.693333
# ..        ...       ...       ...       ...       ...       ...       ...
# 501  0.122671  0.000000  0.164122  0.893617  0.987619  0.219095  0.386667
# 502  0.105293  0.000000  0.164122  0.893617  1.000000  0.202815  0.346667
# 503  0.094381  0.000000  0.164122  0.893617  1.000000  0.107892  0.420000
# 504  0.114514  0.000000  0.164122  0.893617  0.991301  0.131071  0.377778
# 505  0.125072  0.000000  0.164122  0.893617  1.000000  0.169702  0.153333
#
# [506 rows x 15 columns]
# Standard Data
#      Unnamed: 0      crim        zn     indus      chas       nox        rm  \
# 0     -1.728631 -0.419782  0.284830 -1.287909 -0.272599 -0.144217  0.413672
# 1     -1.721785 -0.417339 -0.487722 -0.593381 -0.272599 -0.740262  0.194274
# 2     -1.714939 -0.417342 -0.487722 -0.593381 -0.272599 -0.740262  1.282714
# 3     -1.708093 -0.416750 -0.487722 -1.306878 -0.272599 -0.835284  1.016303
# 4     -1.701247 -0.412482 -0.487722 -1.306878 -0.272599 -0.835284  1.228577
# ..          ...       ...       ...       ...       ...       ...       ...
# 501    1.701247 -0.413229 -0.487722  0.115738 -0.272599  0.158124  0.439316
# 502    1.708093 -0.415249 -0.487722  0.115738 -0.272599  0.158124 -0.234548
# 503    1.714939 -0.413447 -0.487722  0.115738 -0.272599  0.158124  0.984960
# 504    1.721785 -0.407764 -0.487722  0.115738 -0.272599  0.158124  0.725672
# 505    1.728631 -0.415000 -0.487722  0.115738 -0.272599  0.158124 -0.362767
#
#           age       dis       rad       tax   ptratio     black     lstat  \
# 0   -0.120013  0.140214 -0.982843 -0.666608 -1.459000  0.441052 -1.075562
# 1    0.367166  0.557160 -0.867883 -0.987329 -0.303094  0.441052 -0.492439
# 2   -0.265812  0.557160 -0.867883 -0.987329 -0.303094  0.396427 -1.208727
# 3   -0.809889  1.077737 -0.752922 -1.106115  0.113032  0.416163 -1.361517
# 4   -0.511180  1.077737 -0.752922 -1.106115  0.113032  0.441052 -1.026501
# ..        ...       ...       ...       ...       ...       ...       ...
# 501  0.018673 -0.625796 -0.982843 -0.803212  1.176466  0.387217 -0.418147
# 502  0.288933 -0.716639 -0.982843 -0.803212  1.176466  0.441052 -0.500850
# 503  0.797449 -0.773684 -0.982843 -0.803212  1.176466  0.441052 -0.983048
# 504  0.736996 -0.668437 -0.982843 -0.803212  1.176466  0.403225 -0.865302
# 505  0.434732 -0.613246 -0.982843 -0.803212  1.176466  0.441052 -0.669058
#
#          medv
# 0    0.159686
# 1   -0.101524
# 2    1.324247
# 3    1.182758
# 4    1.487503
# ..        ...
# 501 -0.014454
# 502 -0.210362
# 503  0.148802
# 504 -0.057989
# 505 -1.157248
#
# [506 rows x 15 columns]

# %%
# Using User-Defined Functions

def min_max_scaling(df):
    df_norm = df.copy()
    for column in df_norm.columns:
        df_norm[column] = (df_norm[column] - df_norm[column].min()) / (df_norm[column].max() - df_norm[column].min())
    return df_norm
    
df_normalized = min_max_scaling(df1)
print(df_normalized)

def standard_scaling(df):
    df_std = df.copy()
    for column in df_std.columns:
        df_std[column] = (df_std[column] - df_std[column].mean()) / df_std[column].std()
    return df_std
    
df_standardized = standard_scaling(df1)
print(df_standardized)

corr = df1.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(176, 0, n=7),
    square=True,
    linewidths=.5
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    ha='center',
    rotation=45
);
# Out:
#      Unnamed: 0      crim    zn     indus  chas       nox        rm       age  \
# 0      0.000000  0.000000  0.18  0.067815   0.0  0.314815  0.577505  0.641607
# 1      0.001980  0.000236  0.00  0.242302   0.0  0.172840  0.547998  0.782698
# 2      0.003960  0.000236  0.00  0.242302   0.0  0.172840  0.694386  0.599382
# 3      0.005941  0.000293  0.00  0.063050   0.0  0.150206  0.658555  0.441813
# 4      0.007921  0.000705  0.00  0.063050   0.0  0.150206  0.687105  0.528321
# ..          ...       ...   ...       ...   ...       ...       ...       ...
# 501    0.992079  0.000633  0.00  0.420455   0.0  0.386831  0.580954  0.681771
# 502    0.994059  0.000438  0.00  0.420455   0.0  0.386831  0.490324  0.760041
# 503    0.996040  0.000612  0.00  0.420455   0.0  0.386831  0.654340  0.907312
# 504    0.998020  0.001161  0.00  0.420455   0.0  0.386831  0.619467  0.889804
# 505    1.000000  0.000462  0.00  0.420455   0.0  0.386831  0.473079  0.802266
#
#           dis       rad       tax   ptratio     black     lstat      medv
# 0    0.269203  0.000000  0.208015  0.287234  1.000000  0.089680  0.422222
# 1    0.348962  0.043478  0.104962  0.553191  1.000000  0.204470  0.368889
# 2    0.348962  0.043478  0.104962  0.553191  0.989737  0.063466  0.660000
# 3    0.448545  0.086957  0.066794  0.648936  0.994276  0.033389  0.631111
# 4    0.448545  0.086957  0.066794  0.648936  1.000000  0.099338  0.693333
# ..        ...       ...       ...       ...       ...       ...       ...
# 501  0.122671  0.000000  0.164122  0.893617  0.987619  0.219095  0.386667
# 502  0.105293  0.000000  0.164122  0.893617  1.000000  0.202815  0.346667
# 503  0.094381  0.000000  0.164122  0.893617  1.000000  0.107892  0.420000
# 504  0.114514  0.000000  0.164122  0.893617  0.991301  0.131071  0.377778
# 505  0.125072  0.000000  0.164122  0.893617  1.000000  0.169702  0.153333
#
# [506 rows x 15 columns]
#      Unnamed: 0      crim        zn     indus      chas       nox        rm  \
# 0     -1.726922 -0.419367  0.284548 -1.286636 -0.272329 -0.144075  0.413263
# 1     -1.720083 -0.416927 -0.487240 -0.592794 -0.272329 -0.739530  0.194082
# 2     -1.713244 -0.416929 -0.487240 -0.592794 -0.272329 -0.739530  1.281446
# 3     -1.706404 -0.416338 -0.487240 -1.305586 -0.272329 -0.834458  1.015298
# 4     -1.699565 -0.412074 -0.487240 -1.305586 -0.272329 -0.834458  1.227362
# ..          ...       ...       ...       ...       ...       ...       ...
# 501    1.699565 -0.412820 -0.487240  0.115624 -0.272329  0.157968  0.438881
# 502    1.706404 -0.414839 -0.487240  0.115624 -0.272329  0.157968 -0.234316
# 503    1.713244 -0.413038 -0.487240  0.115624 -0.272329  0.157968  0.983986
# 504    1.720083 -0.407361 -0.487240  0.115624 -0.272329  0.157968  0.724955
# 505    1.726922 -0.414590 -0.487240  0.115624 -0.272329  0.157968 -0.362408
#
#           age       dis       rad       tax   ptratio     black     lstat  \
# 0   -0.119895  0.140075 -0.981871 -0.665949 -1.457558  0.440616 -1.074499
# 1    0.366803  0.556609 -0.867024 -0.986353 -0.302794  0.440616 -0.491953
# 2   -0.265549  0.556609 -0.867024 -0.986353 -0.302794  0.396035 -1.207532
# 3   -0.809088  1.076671 -0.752178 -1.105022  0.112920  0.415751 -1.360171
# 4   -0.510674  1.076671 -0.752178 -1.105022  0.112920  0.440616 -1.025487
# ..        ...       ...       ...       ...       ...       ...       ...
# 501  0.018654 -0.625178 -0.981871 -0.802418  1.175303  0.386834 -0.417734
# 502  0.288648 -0.715931 -0.981871 -0.802418  1.175303  0.440616 -0.500355
# 503  0.796661 -0.772919 -0.981871 -0.802418  1.175303  0.440616 -0.982076
# 504  0.736268 -0.667776 -0.981871 -0.802418  1.175303  0.402826 -0.864446
# 505  0.434302 -0.612640 -0.981871 -0.802418  1.175303  0.440616 -0.668397
#
#          medv
# 0    0.159528
# 1   -0.101424
# 2    1.322937
# 3    1.181589
# 4    1.486032
# ..        ...
# 501 -0.014440
# 502 -0.210154
# 503  0.148655
# 504 -0.057932
# 505 -1.156104
#
# [506 rows x 15 columns]
