# %%
### Boston Housing Dataset

# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd  
import seaborn as sns

df1 = pd.read_csv('C:\\Users\\KIIT\\Downloads\\housing.csv')
print(df1.head())
sns.scatterplot(data=df1,x='RM',y='LSTAT')
# Out:
#       RM  LSTAT  PTRATIO      MEDV
# 0  6.575   4.98     15.3  504000.0
# 1  6.421   9.14     17.8  453600.0
# 2  7.185   4.03     17.8  728700.0
# 3  6.998   2.94     18.7  701400.0
# 4  7.147   5.33     18.7  760200.0
# <AxesSubplot:xlabel='RM', ylabel='LSTAT'>

# %%
sns.lineplot(data=df1,x='RM',y='MEDV')
# Out:
# <AxesSubplot:xlabel='RM', ylabel='MEDV'>

# %%
sns.boxplot(data=df1,x='RM',y='MEDV')
# Out:
# <AxesSubplot:xlabel='RM', ylabel='MEDV'>

# %%
sns.pairplot(data=df1)

# %%
corr = df1.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
### INFY.NS.CSV

# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd  
import seaborn as sns

df2 = pd.read_csv('C:\\Users\\KIIT\\Downloads\\INFY.NS.csv')
print(df2.head())
df2.plot(kind = 'scatter', x= 'Open', y='Close')
plt.show()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2020-08-11  949.900024  962.000000  946.099976  948.450012  928.351685
# 1  2020-08-12  948.000000  958.799988  942.200012  954.950012  934.713928
# 2  2020-08-13  954.799988  968.500000  948.250000  951.200012  931.043396
# 3  2020-08-14  955.849976  963.000000  952.049988  953.599976  933.392517
# 4  2020-08-17  954.099976  972.450012  954.099976  957.500000  937.209900
#
#       Volume
# 0  6802442.0
# 1  6908726.0
# 2  5097703.0
# 3  4663873.0
# 4  9008210.0

# %%
df2.plot(kind = 'line', x= 'Open', y='Close')
plt.show()

# %%
df2.plot(kind = 'box', x= 'Open', y='Close')
plt.show()

# %%
import pandas as pd  
import seaborn as sns
sns.pairplot(data=df2)

# %%
import numpy as np
import pandas as pd  
import seaborn as sns
import matplotlib.pyplot as plt
df2 = pd.read_csv('C:\\Users\\KIIT\\Downloads\\INFY.NS.csv')
corr = df2.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>
